# %% [markdown]
# <a href="https://colab.research.google.com/github/alexmonyi/Age-Calculator/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# User Input and While Loops

# %%
#Example user input
message =  input("Enter Your Name?")
print(message)
# Out:
# Enter Your Name?Alex
# Alex

# %%
#Example 2 user input

# %%
fav0rite_book = input("Enter Your Favourite Book?")
print(f"Your favorite book is {fav0rite_book}") #use of the Format String Literal aka F-string
# Out:
# Enter Your Favourite Book?The Bible
# Your favorite book is The Bible

# %% [markdown]
# The while Loop

# %%
#Example 1:
current_number = 1 #we assign current_number the value 1
while current_number <= 5:
  print(current_number)
  current_number= current_number + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Example 2
prompt = "Enter Somethin and I will repeat it back to you!"
prompt += "Enter 'quit' to end the program"
message = ""
while message != 'quit':
  message = input(prompt)
  print(message)
# Out:
# Enter Somethin and I will repeat it back to you!Enter 'quit' to end the program Hello
#  Hello
# Enter Somethin and I will repeat it back to you!Enter 'quit' to end the programHow are you?
# How are you?
# Enter Somethin and I will repeat it back to you!Enter 'quit' to end the programquit
# quit
